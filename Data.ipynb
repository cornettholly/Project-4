# %%
# Dependencies
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier 
from tensorflow import keras

import tensorflow as tf

# %%
file = 'train.csv'

df = pd.read_csv(file)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
get_dummies_df = pd.get_dummies(df).dropna()

get_dummies_df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  \
# ...

# %%
get_dummies_df['GarageYrBlt'].dtypes
# Out:
# dtype('float64')

# %%
df['Neighborhood'].unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
get_dummies_df["sales_price_bin"] = pd.qcut(get_dummies_df['SalePrice'], 10)

get_dummies_df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_New  \
# ...

# %%
get_dummies_df.dtypes
# Out:
# Id                          int64
# MSSubClass                  int64
# LotFrontage               float64
# LotArea                     int64
# OverallQual                 int64
#                            ...
# SaleCondition_Alloca        uint8
# SaleCondition_Family        uint8
# SaleCondition_Normal        uint8
# SaleCondition_Partial       uint8
# sales_price_bin          category
# Length: 291, dtype: object

# %% [markdown]
#  RANFOM FOREST MODEL

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

le.fit(get_dummies_df['sales_price_bin'])

list(le.classes_)
# Out:
# [Interval(35310.999, 109500.0, closed='right'),
#  Interval(109500.0, 125000.0, closed='right'),
#  Interval(125000.0, 136500.0, closed='right'),
#  Interval(136500.0, 148000.0, closed='right'),
#  Interval(148000.0, 164900.0, closed='right'),
#  Interval(164900.0, 180000.0, closed='right'),
#  Interval(180000.0, 202900.0, closed='right'),
#  Interval(202900.0, 239000.0, closed='right'),
#  Interval(239000.0, 290000.0, closed='right'),
#  Interval(290000.0, 755000.0, closed='right')]

# %%
y = le.fit_transform(get_dummies_df.sales_price_bin)

# %%
get_dummies_df.sales_price_bin = le.fit_transform(get_dummies_df.sales_price_bin)

# %%
y
# Out:
# array([7, 6, 7, ..., 8, 3, 3])

# %%
X = get_dummies_df

# %%
X = X.drop(columns=['sales_price_bin'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
import sklearn as skl
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# RANDOM FOREST CLASSIFIER

# %%
#random forest  
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)
rf_model = rf_model.fit(X_train_scaled, y_train)
predictions = rf_model.predict(X_test_scaled)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
print("Confusion Matrix")
acc_score = accuracy_score(y_test, predictions)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
# Accuracy Score : 0.7615658362989324
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        28
#            1       0.96      0.96      0.96        25
#            2       0.79      0.61      0.69        31
#            3       0.67      0.57      0.62        28
#            4       0.58      0.75      0.65        24
#            5       0.59      0.56      0.58        34
#            6       0.50      0.75      0.60        20
#            7       0.90      0.80      0.85        35
#            8       0.83      0.77      0.80        26
#            9       0.87      0.90      0.89        30
#
#     accuracy                           0.76       281
#    macro avg       0.77      0.77      0.76       281
# weighted avg       0.77      0.76      0.76       281

# %% [markdown]
#  KERAS SEQUENTIAL/NN MODEL

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=20, activation="relu"))

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=15, activation="sigmoid"))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=10, activation="linear"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 20)                5820
#
#  dense_4 (Dense)             (None, 15)                315
#
#  dense_5 (Dense)             (None, 10)                160
#
# ...
# Total params: 6,295
# Trainable params: 6,295
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=['mse'])

# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 1ms/step - loss: 33.5933 - mse: 29.9446
# Epoch 2/100
# 27/27 [==============================] - 0s 2ms/step - loss: 23.4052 - mse: 28.7504
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 8.8921 - mse: 27.3793
# Epoch 4/100
# 27/27 [==============================] - 0s 1ms/step - loss: -1.2189 - mse: 26.2871
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/step - loss: -4.0547 - mse: 25.5859
# Epoch 6/100
# 27/27 [==============================] - 0s 1ms/step - loss: -5.8587 - mse: 25.0054
# Epoch 7/100
# 27/27 [==============================] - 0s 1ms/step - loss: -9.2749 - mse: 24.3774
# Epoch 8/100
# 27/27 [==============================] - 0s 2ms/step - loss: -13.1605 - mse: 23.7919
# Epoch 9/100
# 27/27 [==============================] - 0s 1ms/step - loss: -16.4797 - mse: 23.4131
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 9/9 - 0s - loss: -2.9118e+01 - mse: 22.1751 - 397ms/epoch - 44ms/step
# Loss: -29.118114471435547, Accuracy: 22.17507553100586

# %% [markdown]
#  AUTO-OPTIMIZED MODEL THAT FINDS THE TOP MODELS

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=2))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=10,
            step=2),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["mse"])
    
    return nn_model

# %%
! pip install keras_tuner 
import keras_tuner as kt
from tensorflow.keras import layers

class CustomMetric(keras.metrics.Metric):
    def __init__(self, **kwargs):
        # Specify the name of the metric as "custom_metric".
        super().__init__(name="custom_metric", **kwargs)
        self.sum = self.add_weight(name="sum", initializer="zeros")
        self.count = self.add_weight(name="count", dtype=tf.int32, initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, dtype=tf.float32 , name=None)
        values = tf.math.squared_difference(y_pred, y_true)
        count = tf.shape(y_true)[0]
        if sample_weight is not None:
            sample_weight = tf.cast(sample_weight, self.dtype)
            values *= sample_weight
            count *= sample_weight
        self.sum.assign_add(tf.reduce_sum(values))
        self.count.assign_add(count)

    def result(self):
        return self.sum / tf.cast(self.count, tf.float32)

    def reset_states(self):
        self.sum.assign(0)
        self.count.assign(0)



def build_regressor(hp):
    model = keras.Sequential(
        [
            layers.Dense(units=hp.Int("units", 100, 10000, 10), activation="relu"),
            layers.Dense(units=hp.Int("units", 10, 1000, 10), activation="tanh"),
            layers.Dense(units=1),
        ]
    )
    model.compile(
        optimizer="adam",
        loss="mean_squared_error",
        # Put custom metric into the metrics.
        metrics=[CustomMetric()],
    )
    return model


tuner = kt.RandomSearch(
    hypermodel=build_regressor,
    # Specify the name and direction of the objective.
    objective=kt.Objective("val_custom_metric", direction="min"),
    max_trials=20,
    overwrite=True,
    directory="my_dir",
    project_name="custom_metrics",
)

tuner.search(
    x=X_train_scaled,
    y=y_train,
    validation_data=(X_test_scaled,y_test)
)

tuner.results_summary()
# Out:
# Trial 20 Complete [00h 00m 28s]
# val_custom_metric: 8.597326278686523
#
# Best val_custom_metric So Far: 1.2914750576019287
# Total elapsed time: 00h 04m 22s
# Results summary
# Results in my_dir/custom_metrics
# Showing 10 best trials
# Objective(name="val_custom_metric", direction="min")
#
# Trial 08 summary
# Hyperparameters:
# units: 340
# Score: 1.2914750576019287
#
# Trial 13 summary
# Hyperparameters:
# units: 1980
# Score: 3.024329662322998
#
# Trial 06 summary
# Hyperparameters:
# units: 1850
# Score: 3.150338649749756
#
# Trial 11 summary
# Hyperparameters:
# units: 1480
# Score: 3.250936985015869
#
# Trial 07 summary
# Hyperparameters:
# units: 6640
# Score: 3.4685451984405518
#
# Trial 09 summary
# Hyperparameters:
# units: 1910
# Score: 3.702943801879883
#
# Trial 18 summary
# Hyperparameters:
# units: 7660
# Score: 3.9220669269561768
#
# Trial 12 summary
# Hyperparameters:
# units: 2240
# Score: 4.812060832977295
#
# Trial 02 summary
# Hyperparameters:
# units: 3000
# ...

# %% [markdown]
# LINEAR

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
predicted_y_values = model.predict(X)

# %%
# !pip install tensorflow_addons

import tensorflow_addons as tfa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
r2 = r2_score(y, predicted_y_values)

r2
# Out:
# 0.9379204167987443
